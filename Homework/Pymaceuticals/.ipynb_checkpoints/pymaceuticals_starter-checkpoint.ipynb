# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_data_path = "data/Mouse_metadata.csv"
study_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_data = pd.read_csv(mouse_data_path)
study = pd.read_csv(study_path)

# Combine the data into a single dataset
df_mousestudy = mouse_data.merge(study, how='outer', on="Mouse ID")

# Display the data table for preview
df_mousestudy
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
mice_count = len(df_mousestudy["Mouse ID"].unique())
mice_count
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
df_mouse_w_duplicates = df_mousestudy[df_mousestudy.duplicated(subset = ['Mouse ID', 'Timepoint']) == True]
mouse_deleted = df_mouse_w_duplicates["Mouse ID"].unique()
df_mouse_w_duplicates
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID.

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

# Create a copy of original dataframe
df_mousestudy_clean = df_mousestudy.copy()

# Using for loop to traverse the mouse ID that can't be used because of duplicate data
for mouse in mouse_deleted:
    df_mousestudy_clean = df_mousestudy_clean.drop(df_mousestudy_clean[df_mousestudy_clean["Mouse ID"] == mouse].index)

# Preview of the cleaned data that will be used throughout
df_mousestudy_clean
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
mice_count_v2 = len(df_mousestudy_clean["Mouse ID"].unique())

mice_count_v2
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method is the most straighforward, creating multiple series and putting them all together at the end.

df_mean_tumor = df_mousestudy_clean[["Drug Regimen","Tumor Volume (mm3)"]].groupby("Drug Regimen").mean()
df_median_tumor = df_mousestudy_clean[["Drug Regimen","Tumor Volume (mm3)"]].groupby("Drug Regimen").median()
df_var_tumor = df_mousestudy_clean[["Drug Regimen","Tumor Volume (mm3)"]].groupby("Drug Regimen").var()
df_std_tumor = df_mousestudy_clean[["Drug Regimen","Tumor Volume (mm3)"]].groupby("Drug Regimen").std()
df_sem_tumor = df_mousestudy_clean[["Drug Regimen","Tumor Volume (mm3)"]].groupby("Drug Regimen").sem()

df_sum = df_mean_tumor.copy()
df_sum = df_sum.rename(columns={"Tumor Volume (mm3)" : "Mean of Tumor Volume (mm3)"})
df_sum["Median of Tumor Volume (mm3)"] = df_median_tumor["Tumor Volume (mm3)"]
df_sum["Variance of Tumor Volume (mm3)"] = df_var_tumor["Tumor Volume (mm3)"]
df_sum["Standard Deviation of Tumor Volume (mm3)"] = df_std_tumor["Tumor Volume (mm3)"]
df_sum["SEM of Tumor Volume (mm3)"] = df_sem_tumor["Tumor Volume (mm3)"]


df_sum
# Out:
#               Mean of Tumor Volume (mm3)  Median of Tumor Volume (mm3)  \
# Drug Regimen
# Capomulin                      40.675741                     41.557809
# Ceftamin                       52.591172                     51.776157
# Infubinol                      52.884795                     51.820584
# Ketapril                       55.235638                     53.698743
# Naftisol                       54.331565                     52.509285
# Placebo                        54.033581                     52.288934
# Propriva                       52.320930                     50.446266
# Ramicane                       40.216745                     40.673236
# Stelasyn                       54.233149                     52.431737
# Zoniferol                      53.236507                     51.818479
#
#               Variance of Tumor Volume (mm3)  \
# Drug Regimen
# Capomulin                          24.947764
# Ceftamin                           39.290177
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method produces everything in a single groupby function
df_mousestudy_clean[["Drug Regimen","Tumor Volume (mm3)"]].groupby("Drug Regimen").describe()
# Out:
#              Tumor Volume (mm3)                                             \
#                           count       mean       std        min        25%
# Drug Regimen
# Capomulin                 230.0  40.675741  4.994774  23.343598  37.685933
# Ceftamin                  178.0  52.591172  6.268188  45.000000  47.208427
# Infubinol                 178.0  52.884795  6.567243  36.321346  47.312353
# Ketapril                  188.0  55.235638  8.279709  45.000000  48.232987
# Naftisol                  186.0  54.331565  8.134708  45.000000  47.285874
# Placebo                   181.0  54.033581  7.821003  45.000000  47.459053
# Propriva                  148.0  52.320930  6.622085  45.000000  46.894328
# Ramicane                  228.0  40.216745  4.846308  22.050126  36.674635
# Stelasyn                  181.0  54.233149  7.710419  45.000000  48.047139
# Zoniferol                 182.0  53.236507  6.966589  45.000000  47.337876
#
#
#                     50%        75%        max
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.

# Setting up the dataframe for the bar plot
treatment = df_mousestudy_clean[["Mouse ID", "Drug Regimen"]]

# Dropping duplicates of the mouse ID to get the correct count of the mouse
treatment = treatment.drop_duplicates("Mouse ID")

# Count the number of mouse for each drug used
treatment = treatment.groupby("Drug Regimen").count()
treatment = treatment.rename(columns={"Mouse ID":"Mouse Count"})

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
 
treatment.plot(kind = "bar");

plt.title("Number of Mice per Drug Regimen")

plt.show();
plt.tight_layout();

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
fig1, ax1 = plt.subplots(figsize=(5,5))
treatment.plot(kind = "bar", color = 'r', ax=ax1)
ax1.set(ylabel = "Number of Mice",
        xlabel = "Drug Regimen",
        title = "Number of Mice per Drug Regimen");

# %%
# Setting up Dataframe for the pie plot
# Taking the Mouse ID column and the Sex to create a new dataframe
gender_of_mice = df_mousestudy_clean[["Mouse ID", "Sex"]]

# Drop the duplicate mouse ID to obtain the correct number of mice
gender_of_mice = gender_of_mice.drop_duplicates("Mouse ID")

# Counting the number of mice based on their sex
gender_of_mice = gender_of_mice.groupby("Sex").count()
gender_of_mice = gender_of_mice.rename(columns = {"Mouse ID":"Mouse Counts"})

# Reset the index to obtain Sex and Mouse ID column again
gender_of_mice_indexed = gender_of_mice.reset_index()

# Preparing label and data for the pie plot
gender = gender_of_mice_indexed["Sex"]
mouse_count = gender_of_mice_indexed["Mouse Counts"]

gender_of_mice
# Out:
#         Mouse Counts
# Sex
# Female           123
# Male             125

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender_of_mice.plot.pie(subplots = True, figsize=(5,5), autopct='%.2f%%')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002CB8FD34580>],
#       dtype=object)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
fig2, ax2 = plt.subplots(figsize = (5,5))
ax2.pie(mouse_count, labels = gender, colors = ["red","lightskyblue"], autopct = "%1.2f%%");
ax2.set(title = "Mouse Study Gender Distribution");

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# %%
# Create a copy of original dataframe
df_quarts = df_mousestudy_cleaned.copy()

# Drop all duplicate mouse ID and save the last (this can be done as the data is sorted by mouse ID with ascending Timepoint meaning last of the mouse ID is the last timepoint)
df_quarts = df_quarts.drop_duplicates("Mouse ID", keep = 'last')

df_quarts.head()
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 9      k403     Ramicane    Male          21          16         45
# 19     s185    Capomulin  Female           3          17         45
# 29     x401    Capomulin  Female          16          15         45
# 39     m601    Capomulin    Male          22          17         45
# 49     g791     Ramicane    Male          11          16         45
#
#     Tumor Volume (mm3)  Metastatic Sites
# 9            22.050126                 1
# 19           23.343598                 1
# 29           28.484033                 0
# 39           28.430964                 1
# 49           29.128472                 1

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_list = []
tumor_per_drug = []
pot_outlier = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 

# for loops to traverse the drug regimen specified
for drug in treatments:
    # for loops to traverse through dataframe
    for index, row in df_quarts.iterrows():
        # we are extracting the tumor volume data only for the specified drug regimen
        if row['Drug Regimen'] == drug:
            tumor_per_drug = tumor_per_drug + [row["Tumor Volume (mm3)"]]
    
    # Calculation for upper bound and lower bound for each drug regimen
    tumor_per_drug.sort()
    lowerq = np.quantile(tumor_per_drug, 0.25)
    upperq = np.quantile(tumor_per_drug, 0.75)
    iqr = upperq - lowerq
    lower_bound = lowerq - (iqr*1.5)
    upper_bound = upperq + (iqr*1.5)
    for outlier in tumor_per_drug:
        if outlier < lower_bound or outlier > upper_bound:
            pot_outlier = pot_outlier + [outlier]
    print(f'''
    {drug}
    --------------------------------------------
    Final Tumor Volume for all the mice treated: {tumor_per_drug}
    First Quartile data is {lowerq}.
    Third Quartile data is {upperq}.
    Potential Outlier data: {pot_outlier}
    ---------------------------------------------''')
    
    # after traversing through the data frame, save the list of the tumor volume in a list that has an index of the treatments
    tumor_vol_list = tumor_vol_list+[tumor_per_drug]
    
    # Reinitializing the list for the next drug
    tumor_per_drug = []
    pot_outlier = []


    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds
# Out:
#     Capomulin
#     --------------------------------------------
#     Final Tumor Volume for all the mice treated: [23.34359787, 28.43096411, 28.48403281, 30.48598484, 31.02392294, 31.896238399999998, 32.37735684, 33.32909778, 34.45529799, 36.04104736, 37.07402422, 37.31184577, 38.125164399999996, 38.75326548, 38.84687569, 38.93963263, 38.98287774, 39.95234669, 40.1592203, 40.65812366, 40.72857787, 41.48300765, 41.58152074, 46.53920617, 47.68596303]
#     First Quartile data is 32.37735684.
#     Third Quartile data is 40.1592203.
#     Potential Outlier data: []
#     ---------------------------------------------
#
#     Ramicane
#     --------------------------------------------
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig3, ax3 = plt.subplots(figsize = (8,8))
ax3.set_title("Drug Regimen Effect on Mice's Tumor")
ax3.set_ylabel("Final Tumor Volume (mm3)")
ax3.boxplot(tumor_vol_list, labels = treatments);

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

# Generate a copy of data frame with only mouse that is treated with Capomulin
df_mouse_capo = df_mousestudy_cleaned.copy()
df_mouse_capo = df_mouse_capo[df_mouse_capo["Drug Regimen"] == "Capomulin"]

# Obtaining 1 mouse to plot the line graph randomly
random_mouse = df_mouse_capo["Mouse ID"].sample()

# Creating the dataframe for the one mouse treated with Capomulin
df_mouse_line = df_mouse_capo[df_mouse_capo["Mouse ID"] == random_mouse.values[0]]


# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
fig4, ax4 = plt.subplots(figsize = (8,8))
ax4.plot(df_mouse_line["Timepoint"], df_mouse_line["Tumor Volume (mm3)"], color='b', marker="o");
ax4.set(xlabel="Timepoint",
        ylabel="Tumor Volume (mm3)",
        title="Effect of Capomulin on a Mouse's Tumor");

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
df_mouse_scatter = df_mouse_capo[["Mouse ID", "Tumor Volume (mm3)", "Weight (g)"]]

df_mouse_scatter = df_mouse_scatter.groupby("Mouse ID").mean()
df_mouse_scatter.head()

fig5, ax5 = plt.subplots(figsize=(8,8))
ax5.scatter(df_mouse_scatter["Weight (g)"], df_mouse_scatter["Tumor Volume (mm3)"])
ax5.set(xlabel = "Weight of Mouse (g)", ylabel = "Average Tumor Volume (mm3)", title = "Correlation of Weight vs Tumor Volume");

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
x_values = df_mouse_scatter["Weight (g)"]
y_values = df_mouse_scatter["Tumor Volume (mm3)"]
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f'''
The linear regression model equation is: {line_eq}
The correlation coefficient is: r={rvalue}
''')
# Out:
# The linear regression model equation is: y = 0.95x + 21.55
# The correlation coefficient is: r=0.8419363424694718
